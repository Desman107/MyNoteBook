# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def Sigmoid(x):
    return 1/(1+np.exp(-x))

def ReLU(x):
    return np.maximum(0,x)

def tanh(x):
    return np.tanh(x)

# %%
# plt.style.use('seaborn-darkgrid')
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']= False
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 800
plt.ylabel('loss')
plt.xlabel('预测分类为1的概率')
x = np.linspace(0, 1, 1000)
y = np.log(x)
plt.plot(x, y,label='真实值为1时的预测和损失的关系')
y2 = np.log(1-x)
plt.plot(x, y2,label='真实值为0时的预测和损失的关系')
plt.legend()
plt.savefig('log_loss.png',dpi=800, bbox_inches='tight', pad_inches=0.1)
#, transparent=True
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_32400\27654270.py:9: RuntimeWarning: divide by zero encountered in log
#   y = np.log(x)
# C:\Users\Dell\AppData\Local\Temp\ipykernel_32400\27654270.py:11: RuntimeWarning: divide by zero encountered in log
#   y2 = np.log(1-x)

# %%
# plt.style.use('seaborn-darkgrid')
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']= False
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 800
# plt.ylabel('loss')
# plt.xlabel('预测分类为1的概率')
x = np.linspace(-3, 3, 1000)
y = np.tanh(x)
plt.plot(x, y,label='真实值为1时的预测和损失的关系')
# y2 = np.log(1-x)
# plt.plot(x, y2,label='真实值为0时的预测和损失的关系')
# plt.legend()
plt.savefig('tanh.png',dpi=800, bbox_inches='tight', pad_inches=0.1)
#, transparent=True
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # plt.style.use('seaborn-darkgrid')
# ----> 2 plt.rcParams['font.sans-serif']=['SimHei']
#       3 plt.rcParams['axes.unicode_minus']= False
#       4 plt.rcParams['figure.figsize'] = [12, 8]
#
# NameError: name 'plt' is not defined

# %%
# plt.style.use('seaborn-darkgrid')
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']= False
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 800
# plt.ylabel('loss')
# plt.xlabel('预测分类为1的概率')
x = np.linspace(-5, 5, 1000)
y = 1/(1+np.exp(-x))
plt.plot(x, y,label='真实值为1时的预测和损失的关系')
# y2 = np.log(1-x)
# plt.plot(x, y2,label='真实值为0时的预测和损失的关系')
# plt.legend()
plt.savefig('S.png',dpi=800, bbox_inches='tight', pad_inches=0.1)
#, transparent=True
plt.show()

# %%
# plt.style.use('seaborn-darkgrid')
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']= False
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 800
# plt.ylabel('loss')
# plt.xlabel('预测分类为1的概率')
x = np.linspace(-2, 2, 1000)
y = np.maximum(0,x)
plt.plot(x, y,label='真实值为1时的预测和损失的关系')
# y2 = np.log(1-x)
# plt.plot(x, y2,label='真实值为0时的预测和损失的关系')
# plt.legend()
plt.savefig('max.png',dpi=800, bbox_inches='tight', pad_inches=0.1)
#, transparent=True
plt.show()
